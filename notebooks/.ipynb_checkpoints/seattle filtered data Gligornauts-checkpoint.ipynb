# %%
import statsmodels.api as sm
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../data/kc_house_data.csv')

# %%
df['city'] = df['address'].str.split(',').str[1].str.strip()

# %%
df['address'].head()[0]
# Out:
# '2102 Southeast 21st Court, Renton, Washington 98055, United States'

# %%
df['zipcode'] = df['address'].str.split(',').str[-2].str[-5:]

# %%
df['zipcode'].head()
# Out:
# 0    98055
# 1    98133
# 2    98178
# 3    98118
# 4    98027
# Name: zipcode, dtype: object

# %%
df_irs = pd.read_csv('../data/income_by_zip.csv')

# %%
df_wa = df_irs.loc[df_irs['STATE'] == 'WA',['STATE','ZIPCODE','N02650','A02650']]

# %%
df_wa['avg_inc'] = df_wa['A02650']/df_wa['N02650']

# %%
df['zipcode'] = df['zipcode'].astype(int)

# %%
df2 = df.merge(df_wa,left_on='zipcode',right_on='ZIPCODE',how='inner')

# %%
df2['month'] = pd.DatetimeIndex(df2['date']).month

# %%
df2['year'] = pd.DatetimeIndex(df2['date']).year

# %%
df2.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7399300360   5/24/2022  675000.0         4        1.0         1180
# 1  3340401570    3/2/2022  750000.0         3        2.0         1830
# 2  7399301200   3/29/2022  728000.0         4        2.0         2170
# 3  9899200050   3/24/2022  565000.0         4        2.0         1400
# 4  6673070070  12/28/2021  645000.0         3        2.0         1520
#
#    sqft_lot  floors waterfront greenbelt  ...       long    city zipcode  \
# 0      7140     1.0         NO        NO  ... -122.19052  Renton   98055
# 1      7969     1.0         NO        NO  ... -122.21400  Renton   98055
# 2      7520     1.0         NO        NO  ... -122.18974  Renton   98055
# 3     10364     1.5         NO        NO  ... -122.21243  Renton   98055
# 4      8250     1.0         NO        NO  ... -122.18869  Renton   98055
#
#   STATE ZIPCODE   N02650    A02650   avg_inc  month  year
# 0    WA   98055  12360.0  901850.0  72.96521      5  2022
# 1    WA   98055  12360.0  901850.0  72.96521      3  2022
# 2    WA   98055  12360.0  901850.0  72.96521      3  2022
# 3    WA   98055  12360.0  901850.0  72.96521      3  2022
# 4    WA   98055  12360.0  901850.0  72.96521     12  2021
#
# [5 rows x 34 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29220 entries, 0 to 29219
# Data columns (total 34 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             29220 non-null  int64
#  1   date           29220 non-null  object
#  2   price          29220 non-null  float64
#  3   bedrooms       29220 non-null  int64
#  4   bathrooms      29220 non-null  float64
#  5   sqft_living    29220 non-null  int64
#  6   sqft_lot       29220 non-null  int64
#  7   floors         29220 non-null  float64
#  8   waterfront     29220 non-null  object
#  9   greenbelt      29220 non-null  object
#  10  nuisance       29220 non-null  object
#  11  view           29220 non-null  object
#  12  condition      29220 non-null  object
#  13  grade          29220 non-null  object
#  14  heat_source    29194 non-null  object
#  15  sewer_system   29207 non-null  object
#  16  sqft_above     29220 non-null  int64
#  17  sqft_basement  29220 non-null  int64
#  18  sqft_garage    29220 non-null  int64
#  19  sqft_patio     29220 non-null  int64
#  20  yr_built       29220 non-null  int64
#  21  yr_renovated   29220 non-null  int64
#  22  address        29220 non-null  object
#  23  lat            29220 non-null  float64
#  24  long           29220 non-null  float64
#  25  city           29220 non-null  object
#  26  zipcode        29220 non-null  int64
#  27  STATE          29220 non-null  object
#  28  ZIPCODE        29220 non-null  int64
#  29  N02650         29220 non-null  float64
#  30  A02650         29220 non-null  float64
#  31  avg_inc        29220 non-null  float64
#  32  month          29220 non-null  int64
#  33  year           29220 non-null  int64
# dtypes: float64(8), int64(14), object(12)
# memory usage: 7.8+ MB

# %%
df2.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2
                 & ((df2['grade'] != '4 Low') & (df2['grade'] != '12 Luxury') & (df2['grade'] != '11 Excellent')
                 & (df2['grade'] != '10 Very Good') & (df2['grade'] != '9 Better'))].copy()

# %%
df_rich.describe()
# Out:
#                  id         price     bedrooms    bathrooms  sqft_living  \
# count  5.310000e+03  5.310000e+03  5310.000000  5310.000000  5310.000000
# mean   4.726497e+09  8.654838e+05     2.628814     1.822787  1446.779284
# std    2.889000e+09  3.433249e+05     0.483168     0.702395   465.818617
# min    5.200076e+06  3.050000e+04     2.000000     1.000000   540.000000
# 25%    2.436701e+09  6.500000e+05     2.000000     1.000000  1100.000000
# 50%    4.058802e+09  8.000000e+05     3.000000     2.000000  1390.000000
# 75%    7.444500e+09  1.000000e+06     3.000000     2.000000  1710.000000
# max    9.842301e+09  5.825000e+06     3.000000     4.000000  4270.000000
#
#           sqft_lot       floors   sqft_above  sqft_basement  sqft_garage  ...  \
# count  5310.000000  5310.000000  5310.000000    5310.000000  5310.000000  ...
# mean   4257.342561     1.523635  1182.800188     527.949341   116.030508  ...
# std    2373.693853     0.650251   344.420091     429.932243   159.012290  ...
# min     402.000000     1.000000   400.000000       0.000000     0.000000  ...
# 25%    2002.250000     1.000000   940.000000       0.000000     0.000000  ...
# 50%    4313.000000     1.000000  1120.000000     530.000000     0.000000  ...
# 75%    6000.000000     2.000000  1380.000000     880.000000   230.000000  ...
# max    9979.000000     4.000000  3090.000000    2280.000000  1050.000000  ...
#
#                lat         long       zipcode       ZIPCODE        N02650  \
# count  5310.000000  5310.000000   5310.000000   5310.000000   5310.000000
# mean     47.621590  -122.337725  98123.416008  98123.416008  19104.885122
# std       0.070529     0.041019     22.024011     22.024011   6432.584565
# min      47.485030  -122.415595  98102.000000  98102.000000   8720.000000
# 25%      47.553661  -122.372210  98107.000000  98107.000000  13250.000000
# 50%      47.640748  -122.345497  98117.000000  98117.000000  17350.000000
# 75%      47.684241  -122.303078  98126.000000  98126.000000  24860.000000
# max      47.733945  -122.221405  98199.000000  98199.000000  29710.000000
#
#              A02650      avg_inc        month         year  seattle
# count  5.310000e+03  5310.000000  5310.000000  5310.000000   5310.0
# mean   2.551287e+06   134.700559     6.796610  2021.374953      1.0
# std    1.130640e+06    47.176992     3.160441     0.484156      0.0
# min    9.871800e+05    58.030955     1.000000  2021.000000      1.0
# 25%    1.424678e+06    90.751207     4.000000  2021.000000      1.0
# 50%    2.277842e+06   133.069681     7.000000  2021.000000      1.0
# 75%    3.018054e+06   161.456328     9.000000  2022.000000      1.0
# max    4.592189e+06   335.702465    12.000000  2022.000000      1.0
#
# [8 rows x 23 columns]

# %%
df_low = df_rich[df_rich['price'] < 100000]

# %%
df_rich['sqft_lot'].plot(kind='hist');

# %%
df_rich.groupby('grade')['price'].mean().sort_values(ascending=False)
# Out:
# grade
# 8 Good           967595.824324
# 7 Average        865800.384940
# 6 Low Average    671736.898978
# 5 Fair           635800.100000
# Name: price, dtype: float64

# %%
df_rich.groupby('grade')['price'].describe()
# Out:
#                 count           mean            std       min       25%  \
# grade
# 5 Fair           50.0  635800.100000  204654.892822  140000.0  512500.0
# 6 Low Average   881.0  671736.898978  310251.284454   30500.0  525000.0
# 7 Average      2603.0  865800.384940  305226.595308   31190.0  675000.0
# 8 Good         1776.0  967595.824324  369535.135402   50000.0  715000.0
#
#                     50%        75%        max
# grade
# 5 Fair         637500.0   766329.0  1100000.0
# 6 Low Average  645000.0   774500.0  5825000.0
# 7 Average      825000.0  1000000.0  3500000.0
# 8 Good         867750.0  1150000.0  3985000.0

# %%
df_rich['grade'].value_counts(ascending=False)
# Out:
# 7 Average        2603
# 8 Good           1776
# 6 Low Average     881
# 5 Fair             50
# Name: grade, dtype: int64

# %%
df_rich.groupby('condition')['price'].mean().sort_values(ascending=False)
# Out:
# condition
# Very Good    983345.584416
# Good         941166.877001
# Poor         875875.764706
# Average      823754.018228
# Fair         740003.571429
# Name: price, dtype: float64

# %%
df_rich['condition'].value_counts(ascending=False)
# Out:
# Average      3511
# Good         1187
# Very Good     539
# Fair           56
# Poor           17
# Name: condition, dtype: int64

# %%
df_rich['mean_price'] = df_rich['price'].mean()

# %%
df_rich.head()
# Out:
#              id       date      price  bedrooms  bathrooms  sqft_living  \
# 221  6450304798  8/20/2021   730000.0         3        2.0         1570
# 224  2291400343  9/12/2021   539000.0         3        2.5         1290
# 227  6149700160  4/20/2022   675000.0         3        1.0         1250
# 228  2838000130  2/10/2022  1295000.0         3        2.5         2230
# 230  2291400371  7/29/2021   515000.0         2        1.5         1300
#
#      sqft_lot  floors waterfront greenbelt  ... zipcode STATE ZIPCODE  \
# 221      1184     3.0         NO        NO  ...   98133    WA   98133
# 224      1160     2.0         NO        NO  ...   98133    WA   98133
# 227      7500     1.0         NO        NO  ...   98133    WA   98133
# 228      4850     2.0         NO        NO  ...   98133    WA   98133
# 230      1080     2.0         NO        NO  ...   98133    WA   98133
#
#       N02650     A02650    avg_inc  month  year  seattle    mean_price
# 221  25930.0  2194198.0  84.620054      8  2021        1  865483.76629
# 224  25930.0  2194198.0  84.620054      9  2021        1  865483.76629
# 227  25930.0  2194198.0  84.620054      4  2022        1  865483.76629
# 228  25930.0  2194198.0  84.620054      2  2022        1  865483.76629
# 230  25930.0  2194198.0  84.620054      7  2021        1  865483.76629
#
# [5 rows x 36 columns]

# %%
y = df_rich['price']
x = df_rich['mean_price']
model = sm.OLS(y,sm.add_constant(x)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):                nan
# Time:                        07:20:27   Log-Likelihood:                -75218.
# No. Observations:                5310   AIC:                         1.504e+05
# Df Residuals:                    5309   BIC:                         1.504e+05
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# mean_price     1.0000      0.005    183.696      0.000       0.989       1.011
# ==============================================================================
# Omnibus:                     3037.618   Durbin-Watson:                   1.529
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            61012.448
# Skew:                           2.323   Prob(JB):                         0.00
# Kurtosis:                      18.943   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df_rich.corr()['price'].sort_values(ascending=False)
# Out:
# price            1.00000
# sqft_living      0.51640
# sqft_above       0.41027
# avg_inc          0.39601
# sqft_basement    0.35001
# A02650           0.30108
# bathrooms        0.25119
# lat              0.24891
# bedrooms         0.22546
# sqft_patio       0.19245
# year             0.15380
# yr_renovated     0.10175
# sqft_lot         0.09702
# sqft_garage      0.08915
# N02650           0.05734
# mean_price       0.00000
# id              -0.01248
# floors          -0.01310
# zipcode         -0.03984
# ZIPCODE         -0.03984
# long            -0.09870
# month           -0.11412
# yr_built        -0.18889
# seattle              nan
# Name: price, dtype: float64

# %%
df_rich.corr()
# Out:
#                     id    price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1
0.00000 -0.00000  0.00000  0.00000 -0.00000  0.00000 -0.00000
#
#                seattle  mean_price
# id                 nan    -0.00000
# price              nan     0.00000
# bedrooms           nan    -0.00000
# bathrooms          nan    -0.00000
# sqft_living        nan     0.00000
# sqft_lot           nan    -0.00000
# floors             nan    -0.00000
# sqft_above         nan    -0.00000
# sqft_basement      nan     0.00000
# sqft_garage        nan     0.00000
# sqft_patio         nan     0.00000
# yr_built           nan     0.00000
# yr_renovated       nan    -0.00000
# lat                nan     0.00000
# long               nan     0.00000
# zipcode            nan    -0.00000
# ZIPCODE            nan    -0.00000
# N02650             nan     0.00000
# A02650             nan     0.00000
# avg_inc            nan    -0.00000
# month              nan     0.00000
# year               nan    -0.00000
# seattle            nan         nan
# mean_price         nan     1.00000
#
# [24 rows x 24 columns]

# %%
y = df_rich['price']
x = df_rich['sqft_living']
model = sm.OLS(y,sm.add_constant(x)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.267
# Model:                            OLS   Adj. R-squared:                  0.267
# Method:                 Least Squares   F-statistic:                     1930.
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):               0.00
# Time:                        07:20:27   Log-Likelihood:                -74394.
# No. Observations:                5310   AIC:                         1.488e+05
# Df Residuals:                    5308   BIC:                         1.488e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        3.148e+05   1.32e+04     23.911      0.000    2.89e+05    3.41e+05
# sqft_living   380.6050      8.663     43.934      0.000     363.622     397.588
# ==============================================================================
# Omnibus:                     3652.395   Durbin-Watson:                   1.497
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           183837.591
# Skew:                           2.694   Prob(JB):                         0.00
# Kurtosis:                      31.317   Cond. No.                     4.96e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.96e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df_rich.corr()
# Out:
#                     id    price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.00000 -0.01248  -0.01618   -0.02342     -0.00993   0.00545
# price         -0.01248  1.00000   0.22546    0.25119      0.51640   0.09702
# bedrooms      -0.01618  0.22546   1.00000    0.38142      0.49099   0.06785
# bathrooms     -0.02342  0.25119   0.38142    1.00000      0.52951  -0.36443
# sqft_living   -0.00993  0.51640   0.49099    0.52951      1.00000   0.11059
# sqft_lot       0.00545  0.09702   0.06785   -0.36443      0.11059   1.00000
# floors        -0.01567 -0.01310   0.05521    0.47457      0.09936  -0.67497
# sqft_above     0.00102  0.41027   0.40404    0.40510      0.71032   0.06008
# sqft_basement  0.00340  0.35001   0.20555    0.11461      0.51462   0.19074
# sqft_garage    0.00818  0.08915   0.14318    0.25828      0.22382   0.00667
# sqft_patio    -0.02935  0.19245   0.08435    0.19569      0.21338  -0.03510
# yr_built      -0.02813 -0.18889   0.03396    0.47889     -0.00926  -0.56862
# yr_renovated  -0.00861  0.10175   0.00846    0.04811      0.11295   0.06930
# lat           -0.01127  0.24891  -0.01184    0.08281      0.04655  -0.15658
# long           0.06099 -0.09870   0.00807   -0.08126     -0.00638   0.10145
# zipcode       -0.02733 -0.03984   0.00749   -0.07253      0.03810   0.26121
# ZIPCODE       -0.02733 -0.03984   0.00749   -0.07253      0.03810   0.26121
# N02650         0.03234  0.05734  -0.02531    0.00623     -0.03444  -0.13797
# A02650         0.02771  0.30108  -0.01763    0.05013      0.05090  -0.21610
# avg_inc        0.00685  0.39601   0.00382    0.06668      0.13119  -0.14217
# month          0.00775 -0.11412   0.04232    0.01363      0.02274  -0.01137
# year          -0.01100  0.15380  -0.03218   -0.02917     -0.02549   0.01487
# seattle            nan      nan       nan        nan          nan       nan
# mean_price    -0.00000  0.00000  -0.00000   -0.00000      0.00000  -0.00000
#
#                 floors  sqft_above  sqft_basement  sqft_garage  ...     long  \
# id            -0.01567     0.00102        0.00340      0.00818  ...  0.06099
# price         -0.01310     0.41027        0.35001      0.08915  ... -0.09870
# bedrooms       0.05521     0.40404        0.20555      0.14318  ...  0.00807
# N02650        -0.38704 -0.38704  1.00000  0.75328 -0.07301 -0.00478  0.00446
# A02650        -0.34102 -0.34102  0.75328  1.00000  0.56824 -0.01498  0.00697
# avg_inc        0.04313  0.04313 -0.07301  0.56824  1.00000 -0.02019  0.00533
# month         -0.02812 -0.02812 -0.00478 -0.01498 -0.02019  1.00000 -0.84077
# year           0.02224  0.02224  0.00446  0.00697  0.00533 -0.84077  1.00000
# seattle            nan      nan      nan      nan      nan      nan      nan
# mean_price    -0.00000 -0.00000  0.00000  0.00000 -0.00000  0.00000 -0.00000
#
#                seattle  mean_price
# id                 nan    -0.00000
# price              nan     0.00000
# bedrooms           nan    -0.00000
# bathrooms          nan    -0.00000
# sqft_living        nan     0.00000
# sqft_lot           nan    -0.00000
# floors             nan    -0.00000
# sqft_above         nan    -0.00000
# sqft_basement      nan     0.00000
# sqft_garage        nan     0.00000
# sqft_patio         nan     0.00000
# yr_built           nan     0.00000
# yr_renovated       nan    -0.00000
# lat                nan     0.00000
# long               nan     0.00000
# zipcode            nan    -0.00000
# ZIPCODE            nan    -0.00000
# N02650             nan     0.00000
# A02650             nan     0.00000
# avg_inc            nan    -0.00000
# month              nan     0.00000
# year               nan    -0.00000
# seattle            nan         nan
# mean_price         nan     1.00000
#
# [24 rows x 24 columns]

# %%
df_rich.plot.scatter(x='bedrooms',y='price');

# %%
y = df_rich['price']
x = df_rich[['sqft_living','avg_inc']]
model = sm.OLS(y,sm.add_constant(x)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.376
# Model:                            OLS   Adj. R-squared:                  0.376
# Method:                 Least Squares   F-statistic:                     1601.
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):               0.00
# Time:                        07:20:27   Log-Likelihood:                -73964.
# No. Observations:                5310   AIC:                         1.479e+05
# Df Residuals:                    5307   BIC:                         1.480e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        3.414e+04   1.52e+04      2.241      0.025    4280.363     6.4e+04
# sqft_living   348.3074      8.060     43.216      0.000     332.507     364.108
# avg_inc      2430.7552     79.580     30.545      0.000    2274.746    2586.765
# ==============================================================================
# Omnibus:                     4295.111   Durbin-Watson:                   1.749
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           376826.755
# Skew:                           3.287   Prob(JB):                         0.00
# Kurtosis:                      43.743   Cond. No.                     6.24e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.24e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df_rich.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5310 entries, 221 to 27814
# Data columns (total 36 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             5310 non-null   int64
#  1   date           5310 non-null   object
#  2   price          5310 non-null   float64
#  3   bedrooms       5310 non-null   int64
#  4   bathrooms      5310 non-null   float64
#  5   sqft_living    5310 non-null   int64
#  6   sqft_lot       5310 non-null   int64
#  7   floors         5310 non-null   float64
#  8   waterfront     5310 non-null   object
#  9   greenbelt      5310 non-null   object
#  10  nuisance       5310 non-null   object
#  11  view           5310 non-null   object
#  12  condition      5310 non-null   object
#  13  grade          5310 non-null   object
#  14  heat_source    5310 non-null   object
#  15  sewer_system   5307 non-null   object
#  16  sqft_above     5310 non-null   int64
#  17  sqft_basement  5310 non-null   int64
#  18  sqft_garage    5310 non-null   int64
#  19  sqft_patio     5310 non-null   int64
#  20  yr_built       5310 non-null   int64
#  21  yr_renovated   5310 non-null   int64
#  22  address        5310 non-null   object
#  23  lat            5310 non-null   float64
#  24  long           5310 non-null   float64
#  25  city           5310 non-null   object
#  26  zipcode        5310 non-null   int64
#  27  STATE          5310 non-null   object
#  28  ZIPCODE        5310 non-null   int64
#  29  N02650         5310 non-null   float64
#  30  A02650         5310 non-null   float64
#  31  avg_inc        5310 non-null   float64
#  32  month          5310 non-null   int64
#  33  year           5310 non-null   int64
#  34  seattle        5310 non-null   int64
#  35  mean_price     5310 non-null   float64
# dtypes: float64(9), int64(15), object(12)
# memory usage: 1.5+ MB

# %%
df_rich.groupby('bedrooms')['price'].mean().sort_values(ascending=False)
# Out:
# bedrooms
# 3   924949.89158
# 2   764744.34855
# Name: price, dtype: float64

# %%
df_rich['bedrooms'].value_counts(ascending=False)
# Out:
# 3    3339
# 2    1971
# Name: bedrooms, dtype: int64

# %%
cond_list_1 = list(df_rich['condition'].unique())
cond_list_1
# Out:
# ['Average', 'Good', 'Very Good', 'Fair', 'Poor']

# %%
cond_list_2 = [1,1,1,0,0]

# %%
cond_dict = dict(zip(cond_list_1,cond_list_2))
cond_dict
# Out:
# {'Average': 1, 'Good': 1, 'Very Good': 1, 'Fair': 0, 'Poor': 0}

# %%
df_rich['cond_group'] = df_rich['condition'].replace(cond_dict)

# %%
df_rich['avg_inc'].value_counts()
# Out:
# 147.63544    518
# 161.45633    472
# 159.67277    424
# 84.01955     358
# 90.75121     348
# 133.06968    314
# 114.75369    287
# 98.94861     269
# 125.03308    263
# 129.47465    231
# 149.36669    216
# 84.62005     215
# 78.71868     195
# 163.38050    181
# 223.52934    170
# 73.28731     161
# 83.88887     158
# 194.10963    144
# 335.70247    103
# 179.13623     95
# 191.69192     76
# 171.38466     54
# 166.90838     36
# 58.03095      22
# Name: avg_inc, dtype: int64

# %%
df_rich['avg_inc'].plot(kind='hist');

# %%
df_rich.loc[df_rich['avg_inc'] == df_rich['avg_inc'].max()].describe()
# Out:
#                     id         price  bedrooms  bathrooms  sqft_living  \
# count        103.00000     103.00000 103.00000  103.00000    103.00000
# mean  5645715406.69903 1212368.77670   2.59223    1.82524   1588.30097
# std   2864387705.38055  515233.62454   0.49382    0.72663    556.55653
# min    955000095.00000  175259.00000   2.00000    1.00000    610.00000
# 25%   3630000493.50000  870000.00000   2.00000    1.00000   1100.00000
# 50%   5017000560.00000 1180000.00000   3.00000    2.00000   1520.00000
# 75%   8722100935.00000 1400000.00000   3.00000    2.00000   2010.00000
# max   9828702891.00000 3985000.00000   3.00000    4.00000   2950.00000
#
#         sqft_lot    floors  sqft_above  sqft_basement  sqft_garage  ...  \
# count  103.00000 103.00000   103.00000      103.00000    103.00000  ...
# mean  3657.82524   1.55825  1294.85437      599.22330     82.42718  ...
# std   1643.33140   0.50147   456.19669      388.22797    138.66638  ...
# min    536.00000   1.00000   610.00000        0.00000      0.00000  ...
# 25%   2925.00000   1.00000   960.00000      340.00000      0.00000  ...
# 50%   4000.00000   1.50000  1240.00000      580.00000      0.00000  ...
# 75%   4400.00000   2.00000  1585.00000      945.00000    200.00000  ...
# max   8400.00000   3.00000  2870.00000     1350.00000    610.00000  ...
#
#           zipcode     ZIPCODE      N02650        A02650   avg_inc     month  \
# count   103.00000   103.00000   103.00000     103.00000 103.00000 103.00000
# mean  98112.00000 98112.00000 12170.00000 4085499.00000 335.70247   6.62136
# std       0.00000     0.00000     0.00000       0.00000   0.00000   3.38137
# min   98112.00000 98112.00000 12170.00000 4085499.00000 335.70247   1.00000
# 25%   98112.00000 98112.00000 12170.00000 4085499.00000 335.70247   4.00000
# 50%   98112.00000 98112.00000 12170.00000 4085499.00000 335.70247   7.00000
# 75%   98112.00000 98112.00000 12170.00000 4085499.00000 335.70247   9.00000
# max   98112.00000 98112.00000 12170.00000 4085499.00000 335.70247  12.00000
#
#             year   seattle   mean_price  cond_group
# count  103.00000 103.00000    103.00000   103.00000
# mean  2021.36893   1.00000 865483.76629     0.99029
# std      0.48487   0.00000      0.00000     0.09853
# min   2021.00000   1.00000 865483.76629     0.00000
# 25%   2021.00000   1.00000 865483.76629     1.00000
# 50%   2021.00000   1.00000 865483.76629     1.00000
# 75%   2022.00000   1.00000 865483.76629     1.00000
# max   2022.00000   1.00000 865483.76629     1.00000
#
# [8 rows x 25 columns]

# %%
sns.boxplot(x=df_rich['grade'],y=df_rich['price']);

# %%
sns.boxplot(x=df_rich['cond_group'],y=df_rich['price']);

# %%
sns.boxplot(x=df_rich['year'],y=df_rich['price']);

# %%
sns.boxplot(x=df_rich['bedrooms'],y=df_rich['price']);

# %%
sns.scatterplot(x=df_rich['avg_inc'],y=df_rich['price']);

# %%
sns.scatterplot(x=df_rich['sqft_living'],y=df_rich['price']);

# %%
def inc_bins(row):
    if row['avg_inc'] < 100:
        return 0
    elif 100 <= row['avg_inc'] < 150:
        return 1
    else:
        return 2

# %%
df_rich['avg_inc_bins'] = df_rich.apply(inc_bins,axis=1)

# %%
df_rich['avg_inc_bins'].value_counts()
# Out:
# 1    1829
# 2    1755
# 0    1726
# Name: avg_inc_bins, dtype: int64

# %%
df_rich_remove = df_rich.loc[(df_rich['price'] < 2000000) & (df_rich['avg_inc'] < 200000)]

# %%
df_final = pd.get_dummies(data = df_rich_remove,columns = ['bedrooms','cond_group','grade','year','avg_inc_bins'],drop_first = True)

# %%
df_final.head()
# Out:
#              id       date         price  bathrooms  sqft_living  sqft_lot  \
# 221  6450304798  8/20/2021  730000.00000    2.00000         1570      1184
# 224  2291400343  9/12/2021  539000.00000    2.50000         1290      1160
# 227  6149700160  4/20/2022  675000.00000    1.00000         1250      7500
# 228  2838000130  2/10/2022 1295000.00000    2.50000         2230      4850
# 230  2291400371  7/29/2021  515000.00000    1.50000         1300      1080
#
#      floors waterfront greenbelt nuisance  ... seattle   mean_price  \
# 221 3.00000         NO        NO       NO  ...       1 865483.76629
# 224 2.00000         NO        NO      YES  ...       1 865483.76629
# 227 1.00000         NO        NO       NO  ...       1 865483.76629
# 228 2.00000         NO        NO      YES  ...       1 865483.76629
# 230 2.00000         NO        NO       NO  ...       1 865483.76629
#
#     bedrooms_3 cond_group_1  grade_6 Low Average  grade_7 Average  \
# 221          1            1                    0                0
# 224          1            1                    0                1
# 227          1            1                    0                1
# 228          1            1                    0                0
# 230          0            1                    0                0
#
#      grade_8 Good  year_2022  avg_inc_bins_1  avg_inc_bins_2
# 221             1          0               0               0
# 224             0          0               0               0
# 227             0          1               0               0
# 228             1          1               0               0
# 230             1          0               0               0
#
# [5 rows x 41 columns]

# %%
df_final.corr()['price'].sort_values(ascending=False)
# Out:
# price                  1.00000
# sqft_living            0.54709
# avg_inc                0.42915
# sqft_above             0.41617
# sqft_basement          0.37849
# A02650                 0.33416
# avg_inc_bins_2         0.32792
# lat                    0.28532
# bathrooms              0.27452
# bedrooms_3             0.26046
# grade_8 Good           0.22568
# sqft_patio             0.19263
# year_2022              0.16557
# sqft_garage            0.10518
# sqft_lot               0.08780
# yr_renovated           0.08516
# avg_inc_bins_1         0.07587
# N02650                 0.07188
# cond_group_1           0.06767
# grade_7 Average        0.02068
# mean_price            -0.00000
# floors                -0.01868
# id                    -0.03057
# ZIPCODE               -0.04674
# zipcode               -0.04674
# long                  -0.12558
# month                 -0.13050
# yr_built              -0.17510
# grade_6 Low Average   -0.29463
# seattle                    nan
# Name: price, dtype: float64

# %%
y1 = df_final['price']
x1 = df_final['sqft_living']
model = sm.OLS(y1,sm.add_constant(x1)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.299
# Model:                            OLS   Adj. R-squared:                  0.299
# Method:                 Least Squares   F-statistic:                     2246.
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):               0.00
# Time:                        07:20:29   Log-Likelihood:                -72762.
# No. Observations:                5260   AIC:                         1.455e+05
# Df Residuals:                    5258   BIC:                         1.455e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        3.436e+05   1.12e+04     30.687      0.000    3.22e+05    3.66e+05
# sqft_living   351.0644      7.408     47.392      0.000     336.542     365.587
# ==============================================================================
# Omnibus:                      330.678   Durbin-Watson:                   1.468
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              755.950
# Skew:                           0.398   Prob(JB):                    7.04e-165
# Kurtosis:                       4.678   Cond. No.                     4.98e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.98e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from statsmodels.tools.eval_measures import rmse
ypred = model.predict(sm.add_constant(x1))
rmse = rmse(y1, ypred)
rmse
# Out:
# 246277.18327850464

# %%
y_final = df_final['price']
x_final = pd.concat([df_final['sqft_living'],df_final.iloc[:,-8:-6],df_final.iloc[:,-3:]],axis=1)
model = sm.OLS(y_final,sm.add_constant(x_final)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.473
# Model:                            OLS   Adj. R-squared:                  0.472
# Method:                 Least Squares   F-statistic:                     785.4
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):               0.00
# Time:                        07:20:29   Log-Likelihood:                -72014.
# No. Observations:                5260   AIC:                         1.440e+05
# Df Residuals:                    5253   BIC:                         1.441e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           9.311e+04   2.69e+04      3.464      0.001    4.04e+04    1.46e+05
# sqft_living      318.7331      7.480     42.614      0.000     304.070     333.396
# bedrooms_3      1.473e+04   7040.954      2.091      0.037     922.418    2.85e+04
# cond_group_1     9.73e+04   2.56e+04      3.800      0.000    4.71e+04    1.47e+05
# year_2022       1.105e+05   6098.737     18.124      0.000    9.86e+04    1.22e+05
# avg_inc_bins_1  1.828e+05   7218.141     25.327      0.000    1.69e+05    1.97e+05
# avg_inc_bins_2   2.67e+05   7347.718     36.335      0.000    2.53e+05    2.81e+05
# ==============================================================================
# Omnibus:                      443.316   Durbin-Watson:                   1.792
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1927.542
# Skew:                           0.308   Prob(JB):                         0.00
# Kurtosis:                       5.901   Cond. No.                     1.87e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.87e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from statsmodels.tools.eval_measures import rmse
ypred = model.predict(sm.add_constant(x_final))
rmse = rmse(y_final, ypred)
rmse
# Out:
# 213608.25982185357

# %%
sns.boxplot(x=df_rich_remove['grade'],y=df_rich_remove['price']);

# %%
sns.boxplot(x=df_rich_remove['cond_group'],y=df_rich_remove['price']);

# %%
sns.boxplot(x=df_rich_remove['year'],y=df_rich_remove['price']);

# %%
sns.boxplot(x=df_rich_remove['bedrooms'],y=df_rich_remove['price']);

# %%
sns.boxplot(x=df_rich_remove['avg_inc_bins'],y=df_rich_remove['price']);

# %%
y_final = df_final['price']
x_final = df_final.iloc[:,-9]
model = sm.OLS(y_final,sm.add_constant(x_final)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):                nan
# Time:                        07:20:29   Log-Likelihood:                -73698.
# No. Observations:                5260   AIC:                         1.474e+05
# Df Residuals:                    5259   BIC:                         1.474e+05
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# mean_price     0.9813      0.005    209.346      0.000       0.972       0.991
# ==============================================================================
# Omnibus:                      566.270   Durbin-Watson:                   1.518
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              826.187
# Skew:                           0.817   Prob(JB):                    3.94e-180
# Kurtosis:                       4.050   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y_final = df_final['price']
x_final = df_final.iloc[:,-8:-3]
model = sm.OLS(y_final,sm.add_constant(x_final)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.150
# Model:                            OLS   Adj. R-squared:                  0.150
# Method:                 Least Squares   F-statistic:                     186.1
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):          5.11e-183
# Time:                        07:20:29   Log-Likelihood:                -73269.
# No. Observations:                5260   AIC:                         1.465e+05
# Df Residuals:                    5254   BIC:                         1.466e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                5.392e+05   4.91e+04     10.984      0.000    4.43e+05    6.35e+05
# bedrooms_3            1.21e+05   7952.905     15.214      0.000    1.05e+05    1.37e+05
# cond_group_1         8.476e+04   3.26e+04      2.602      0.009    2.09e+04    1.49e+05
# grade_6 Low Average -1.593e+04   3.95e+04     -0.403      0.687   -9.34e+04    6.15e+04
# grade_7 Average      1.522e+05    3.9e+04      3.905      0.000    7.58e+04    2.29e+05
# grade_8 Good         2.358e+05   3.92e+04      6.013      0.000    1.59e+05    3.13e+05
# ==============================================================================
# Omnibus:                      504.007   Durbin-Watson:                   1.573
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              747.760
# Skew:                           0.735   Prob(JB):                    4.23e-163
# Kurtosis:                       4.120   Cond. No.                         35.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y_final = df_final['price']
x_final = df_final.iloc[:,-2:]
model = sm.OLS(y_final,sm.add_constant(x_final)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.186
# Model:                            OLS   Adj. R-squared:                  0.186
# Method:                 Least Squares   F-statistic:                     601.4
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):          6.53e-236
# Time:                        07:20:29   Log-Likelihood:                -73156.
# No. Observations:                5260   AIC:                         1.463e+05
# Df Residuals:                    5257   BIC:                         1.463e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           6.787e+05   6394.085    106.149      0.000    6.66e+05    6.91e+05
# avg_inc_bins_1  2.014e+05   8936.954     22.540      0.000    1.84e+05    2.19e+05
# avg_inc_bins_2  3.085e+05   9037.367     34.140      0.000    2.91e+05    3.26e+05
# ==============================================================================
# Omnibus:                      620.989   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1080.546
# Skew:                           0.798   Prob(JB):                    2.30e-235
# Kurtosis:                       4.545   Cond. No.                         3.76
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y_final = df_final['price']
x_final = df_final.iloc[:,-3]
model = sm.OLS(y_final,sm.add_constant(x_final)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     148.2
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):           1.21e-33
# Time:                        07:20:29   Log-Likelihood:                -73625.
# No. Observations:                5260   AIC:                         1.473e+05
# Df Residuals:                    5258   BIC:                         1.473e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8.117e+05   5056.448    160.526      0.000    8.02e+05    8.22e+05
# year_2022   1.007e+05   8270.783     12.174      0.000    8.45e+04    1.17e+05
# ==============================================================================
# Omnibus:                      520.580   Durbin-Watson:                   1.499
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              761.967
# Skew:                           0.760   Prob(JB):                    3.47e-166
# Kurtosis:                       4.079   Cond. No.                         2.43
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y_final = df_final['price']
x_final = df_final.iloc[:,-12:-9]
model = sm.OLS(y_final,sm.add_constant(x_final)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.199
# Model:                            OLS   Adj. R-squared:                  0.199
# Method:                 Least Squares   F-statistic:                     654.5
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):          1.50e-254
# Time:                        07:20:29   Log-Likelihood:                -73113.
# No. Observations:                5260   AIC:                         1.462e+05
# Df Residuals:                    5257   BIC:                         1.463e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# avg_inc     2677.4193     77.380     34.601      0.000    2525.723    2829.116
# month      -1.148e+04   1148.924     -9.988      0.000   -1.37e+04   -9223.005
# seattle     5.676e+05   1.36e+04     41.730      0.000    5.41e+05    5.94e+05
# ==============================================================================
# Omnibus:                      575.737   Durbin-Watson:                   1.847
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1138.390
# Skew:                           0.705   Prob(JB):                    6.34e-248
# Kurtosis:                       4.790   Cond. No.                         534.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y_final = df_final['price']
x_final = df_final.iloc[:,-12:-8]
model = sm.OLS(y_final,sm.add_constant(x_final)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.199
# Model:                            OLS   Adj. R-squared:                  0.199
# Method:                 Least Squares   F-statistic:                     654.5
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):          1.50e-254
# Time:                        07:20:29   Log-Likelihood:                -73113.
# No. Observations:                5260   AIC:                         1.462e+05
# Df Residuals:                    5257   BIC:                         1.463e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# avg_inc     2677.4193     77.380     34.601      0.000    2525.723    2829.116
# month      -1.148e+04   1148.924     -9.988      0.000   -1.37e+04   -9223.005
# seattle     7.578e-07   1.82e-08     41.730      0.000    7.22e-07    7.93e-07
# mean_price     0.6559      0.016     41.730      0.000       0.625       0.687
# ==============================================================================
# Omnibus:                      575.737   Durbin-Watson:                   1.847
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1138.390
# Skew:                           0.705   Prob(JB):                    6.34e-248
# Kurtosis:                       4.790   Cond. No.                     1.14e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.01e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
from statsmodels.tools.eval_measures import rmse
ypred = model.predict(sm.add_constant(x_final))
rmse = rmse(y_final, ypred)
rmse
# Out:
# 263255.5040864505

# %%
y_final = df_final['price']
x_final = df_final['sqft_living']
model = sm.OLS(y_final,sm.add_constant(x_final)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.299
# Model:                            OLS   Adj. R-squared:                  0.299
# Method:                 Least Squares   F-statistic:                     2246.
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):               0.00
# Time:                        07:20:35   Log-Likelihood:                -72762.
# No. Observations:                5260   AIC:                         1.455e+05
# Df Residuals:                    5258   BIC:                         1.455e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        3.436e+05   1.12e+04     30.687      0.000    3.22e+05    3.66e+05
# sqft_living   351.0644      7.408     47.392      0.000     336.542     365.587
# ==============================================================================
# Omnibus:                      330.678   Durbin-Watson:                   1.468
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              755.950
# Skew:                           0.398   Prob(JB):                    7.04e-165
# Kurtosis:                       4.678   Cond. No.                     4.98e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.98e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df_final.head()
# Out:
#              id       date         price  bathrooms  sqft_living  sqft_lot  \
# 221  6450304798  8/20/2021  730000.00000    2.00000         1570      1184
# 224  2291400343  9/12/2021  539000.00000    2.50000         1290      1160
# 227  6149700160  4/20/2022  675000.00000    1.00000         1250      7500
# 228  2838000130  2/10/2022 1295000.00000    2.50000         2230      4850
# 230  2291400371  7/29/2021  515000.00000    1.50000         1300      1080
#
#      floors waterfront greenbelt nuisance  ... seattle   mean_price  \
# 221 3.00000         NO        NO       NO  ...       1 865483.76629
# 224 2.00000         NO        NO      YES  ...       1 865483.76629
# 227 1.00000         NO        NO       NO  ...       1 865483.76629
# 228 2.00000         NO        NO      YES  ...       1 865483.76629
# 230 2.00000         NO        NO       NO  ...       1 865483.76629
#
#     bedrooms_3 cond_group_1  grade_6 Low Average  grade_7 Average  \
# 221          1            1                    0                0
# 224          1            1                    0                1
# 227          1            1                    0                1
# 228          1            1                    0                0
# 230          0            1                    0                0
#
#      grade_8 Good  year_2022  avg_inc_bins_1  avg_inc_bins_2
# 221             1          0               0               0
# 224             0          0               0               0
# 227             0          1               0               0
# 228             1          1               0               0
# 230             1          0               0               0
#
# [5 rows x 41 columns]

# %%
df['']
