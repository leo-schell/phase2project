# %%
import statsmodels.api as sm
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('../data/kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7399300360   5/24/2022  675000.0         4        1.0         1180
# 1  8910500230  12/13/2021  920000.0         5        2.5         2770
# 2  1180000275   9/29/2021  311000.0         6        2.0         2880
# 3  1604601802  12/14/2021  775000.0         3        3.0         2160
# 4  8562780790   8/24/2021  592500.0         2        2.0         1120
#
#    sqft_lot  floors waterfront greenbelt  ... sewer_system sqft_above  \
# 0      7140     1.0         NO        NO  ...       PUBLIC       1180
# 1      6703     1.0         NO        NO  ...       PUBLIC       1570
# 2      6156     1.0         NO        NO  ...       PUBLIC       1580
# 3      1400     2.0         NO        NO  ...       PUBLIC       1090
# 4       758     2.0         NO        NO  ...       PUBLIC       1120
#
#   sqft_basement sqft_garage sqft_patio yr_built  yr_renovated  \
# 0             0           0         40     1969             0
# 1          1570           0        240     1950             0
# 2          1580           0          0     1956             0
# 3          1070         200        270     2010             0
# 4           550         550         30     2012             0
#
#                                              address        lat       long
# 0  2102 Southeast 21st Court, Renton, Washington ...  47.461975 -122.19052
# 1  11231 Greenwood Avenue North, Seattle, Washing...  47.711525 -122.35591
# 2  8504 South 113th Street, Seattle, Washington 9...  47.502045 -122.22520
# 3  4079 Letitia Avenue South, Seattle, Washington...  47.566110 -122.29020
# 4  2193 Northwest Talus Drive, Issaquah, Washingt...  47.532470 -122.07188
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30155 entries, 0 to 30154
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             30155 non-null  int64
#  1   date           30155 non-null  object
#  2   price          30155 non-null  float64
#  3   bedrooms       30155 non-null  int64
#  4   bathrooms      30155 non-null  float64
#  5   sqft_living    30155 non-null  int64
#  6   sqft_lot       30155 non-null  int64
#  7   floors         30155 non-null  float64
#  8   waterfront     30155 non-null  object
#  9   greenbelt      30155 non-null  object
#  10  nuisance       30155 non-null  object
#  11  view           30155 non-null  object
#  12  condition      30155 non-null  object
#  13  grade          30155 non-null  object
#  14  heat_source    30123 non-null  object
#  15  sewer_system   30141 non-null  object
#  16  sqft_above     30155 non-null  int64
#  17  sqft_basement  30155 non-null  int64
#  18  sqft_garage    30155 non-null  int64
#  19  sqft_patio     30155 non-null  int64
#  20  yr_built       30155 non-null  int64
#  21  yr_renovated   30155 non-null  int64
#  22  address        30155 non-null  object
#  23  lat            30155 non-null  float64
#  24  long           30155 non-null  float64
# dtypes: float64(5), int64(10), object(10)
# memory usage: 5.8+ MB

# %%
df['address'].head()
# Out:
# 0    2102 Southeast 21st Court, Renton, Washington ...
# 1    11231 Greenwood Avenue North, Seattle, Washing...
# 2    8504 South 113th Street, Seattle, Washington 9...
# 3    4079 Letitia Avenue South, Seattle, Washington...
# 4    2193 Northwest Talus Drive, Issaquah, Washingt...
# Name: address, dtype: object

# %%
seattle = df[df['address'].str.contains(pat = 'Seattle')]
seattle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9376 entries, 1 to 30152
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             9376 non-null   int64
#  1   date           9376 non-null   object
#  2   price          9376 non-null   float64
#  3   bedrooms       9376 non-null   int64
#  4   bathrooms      9376 non-null   float64
#  5   sqft_living    9376 non-null   int64
#  6   sqft_lot       9376 non-null   int64
#  7   floors         9376 non-null   float64
#  8   waterfront     9376 non-null   object
#  9   greenbelt      9376 non-null   object
#  10  nuisance       9376 non-null   object
#  11  view           9376 non-null   object
#  12  condition      9376 non-null   object
#  13  grade          9376 non-null   object
#  14  heat_source    9375 non-null   object
#  15  sewer_system   9372 non-null   object
#  16  sqft_above     9376 non-null   int64
#  17  sqft_basement  9376 non-null   int64
#  18  sqft_garage    9376 non-null   int64
#  19  sqft_patio     9376 non-null   int64
#  20  yr_built       9376 non-null   int64
#  21  yr_renovated   9376 non-null   int64
#  22  address        9376 non-null   object
#  23  lat            9376 non-null   float64
#  24  long           9376 non-null   float64
# dtypes: float64(5), int64(10), object(10)
# memory usage: 1.9+ MB

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df['price'].describe()
# Out:
# count      30155.00000
# mean     1108535.83787
# std       896385.65919
# min        27360.00000
# 25%       648000.00000
# 50%       860000.00000
# 75%      1300000.00000
# max     30750000.00000
# Name: price, dtype: float64

# %%
df['grade'].value_counts()
# Out:
# 7 Average        11697
# 8 Good            9410
# 9 Better          3806
# 6 Low Average     2858
# 10 Very Good      1371
# 11 Excellent       406
# 5 Fair             393
# 12 Luxury          122
# 4 Low               51
# 13 Mansion          24
# 3 Poor              13
# 1 Cabin              2
# 2 Substandard        2
# Name: grade, dtype: int64

# %%
df['bedrooms'].value_counts()
# Out:
# 3     12754
# 4      9597
# 2      3936
# 5      2798
# 6       498
# 1       391
# 7        80
# 0        44
# 8        38
# 9        14
# 10        3
# 11        1
# 13        1
# Name: bedrooms, dtype: int64

# %%
zerobeds = df[(df['bedrooms'] == 0)]
zerobeds.head()
# Out:
#               id        date         price  bedrooms  bathrooms  sqft_living  \
# 573   3920030050   5/19/2022  930000.00000         0    0.00000         1617
# 1289  2768301406    3/2/2022 1090000.00000         0    0.00000         1500
# 1310  3462800015  11/10/2021  360000.00000         0    0.00000          910
# 1952  2020069042   9/27/2021  399990.00000         0    0.00000         1677
# 2044  6896300047   9/17/2021  509000.00000         0    1.00000          400
#
#       sqft_lot  floors waterfront greenbelt  ... sewer_system sqft_above  \
# 573       2156 3.00000         NO        NO  ...       PUBLIC       2156
# 1289      1262 3.00000         NO        NO  ...       PUBLIC       1500
# 1310     19000 1.00000         NO        NO  ...      PRIVATE        910
# 1952     43264 1.00000         NO        NO  ...       PUBLIC       1677
# 2044      2385 1.00000         NO        NO  ...       PUBLIC        400
#
#      sqft_basement sqft_garage sqft_patio yr_built  yr_renovated  \
# 573              0           0          0     2009             0
# 1289             0           0          0     2021             0
# 1310             0           0        250     1946             0
# 1952             0           0          0     1969             0
# 2044             0           0          0     1946             0
#
#                                                 address      lat       long
# 573   6019 Roosevelt Way Northeast, Seattle, Washing... 47.67270 -122.31781
# 1289         A, Leadwood, Missouri 63653, United States 37.85979  -90.58113
# 1310  26125 79th Avenue South, Kent, Washington 9803... 47.36677 -122.23543
# 1952  43407 212th Avenue Southeast, Enumclaw, Washin... 47.21166 -122.05920
# 2044  8416 B Island Dr S, Seattle, Washington 98118,... 47.52803 -122.26129
#
# [5 rows x 25 columns]

# %%
#John's code

df['city'] = df['address'].str.split(',').str[1].str.strip()
df['zipcode'] = df['address'].str.split(',').str[-2].str[-5:]
df['zipcode'].head()
df_irs = pd.read_csv('../data/income_by_zip.csv')
df_wa = df_irs.loc[df_irs['STATE'] == 'WA',['STATE','ZIPCODE','N02650','A02650']]
df_wa['avg_inc'] = df_wa['A02650']/df_wa['N02650']
df['zipcode'] = df['zipcode'].astype(int)
df2 = df.merge(df_wa,left_on='zipcode',right_on='ZIPCODE',how='inner')
df2['month'] = pd.DatetimeIndex(df2['date']).month
df2['year'] = pd.DatetimeIndex(df2['date']).year

# %%
pd.set_option('display.max_rows', None)
df2['city'].value_counts()
seattle = df2[(df2['city'] == 'Seattle')]
seattle.head()
# Out:
#              id        date         price  bedrooms  bathrooms  sqft_living  \
# 219  8910500230  12/13/2021  920000.00000         5    2.50000         2770
# 221  6450304798   8/20/2021  730000.00000         3    2.00000         1570
# 223  2683100015   9/10/2021  835000.00000         4    1.50000         2650
# 224  2291400343   9/12/2021  539000.00000         3    2.50000         1290
# 225  3034200190   6/25/2021 1395000.00000         4    2.00000         3320
#
#      sqft_lot  floors waterfront greenbelt  ...       long     city zipcode  \
# 219      6703 1.00000         NO        NO  ... -122.35591  Seattle   98133
# 221      1184 3.00000         NO        NO  ... -122.34358  Seattle   98133
# 223      8129 1.50000         NO        NO  ... -122.33209  Seattle   98133
# 224      1160 2.00000         NO        NO  ... -122.34516  Seattle   98133
# 225     23940 1.00000         NO        NO  ... -122.33135  Seattle   98133
#
#     STATE ZIPCODE      N02650        A02650  avg_inc  month  year
# 219    WA   98133 25930.00000 2194198.00000 84.62005     12  2021
# 221    WA   98133 25930.00000 2194198.00000 84.62005      8  2021
# 223    WA   98133 25930.00000 2194198.00000 84.62005      9  2021
# 224    WA   98133 25930.00000 2194198.00000 84.62005      9  2021
# 225    WA   98133 25930.00000 2194198.00000 84.62005      6  2021
#
# [5 rows x 34 columns]

# %%
# >= 2 bedroom home for families making 50% - 80% of king county family average (120k) = 60k - 96k
seattle['bedrooms'].describe()
# Out:
# count   9368.00000
# mean       3.18072
# std        1.06444
# min        0.00000
# 25%        2.00000
# 50%        3.00000
# 75%        4.00000
# max       11.00000
# Name: bedrooms, dtype: float64

# %%
#exploring 11 bedrooms
q = seattle.loc[seattle['bedrooms'] == 11]
pd.set_option('display.max_colwidth', None)
q['address']
# Out:
# 25935    5205 11th Avenue Northeast, Seattle, Washington 98105, United States
# Name: address, dtype: object

# %% [markdown]
# redfin listings:
# 11 bedrooms
# https://www.redfin.com/WA/Seattle/5205-11th-Ave-NE-98105/home/312092

# %%
#2-5 bedrooms
seattle_beds = seattle[(seattle['bedrooms'] > 1) & (seattle['bedrooms'] < 6)]
seattle_beds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8929 entries, 219 to 27814
# Data columns (total 34 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             8929 non-null   int64
#  1   date           8929 non-null   object
#  2   price          8929 non-null   float64
#  3   bedrooms       8929 non-null   int64
#  4   bathrooms      8929 non-null   float64
#  5   sqft_living    8929 non-null   int64
#  6   sqft_lot       8929 non-null   int64
#  7   floors         8929 non-null   float64
#  8   waterfront     8929 non-null   object
#  9   greenbelt      8929 non-null   object
#  10  nuisance       8929 non-null   object
#  11  view           8929 non-null   object
#  12  condition      8929 non-null   object
#  13  grade          8929 non-null   object
#  14  heat_source    8929 non-null   object
#  15  sewer_system   8925 non-null   object
#  16  sqft_above     8929 non-null   int64
#  17  sqft_basement  8929 non-null   int64
#  18  sqft_garage    8929 non-null   int64
#  19  sqft_patio     8929 non-null   int64
#  20  yr_built       8929 non-null   int64
#  21  yr_renovated   8929 non-null   int64
#  22  address        8929 non-null   object
#  23  lat            8929 non-null   float64
#  24  long           8929 non-null   float64
#  25  city           8929 non-null   object
#  26  zipcode        8929 non-null   int64
#  27  STATE          8929 non-null   object
#  28  ZIPCODE        8929 non-null   int64
#  29  N02650         8929 non-null   float64
#  30  A02650         8929 non-null   float64
#  31  avg_inc        8929 non-null   float64
#  32  month          8929 non-null   int64
#  33  year           8929 non-null   int64
# dtypes: float64(8), int64(14), object(12)
# memory usage: 2.4+ MB

# %%
seattle_beds['bedrooms'].value_counts()
# Out:
# 3    3969
# 2    2152
# 4    2147
# 5     661
# Name: bedrooms, dtype: int64

# %%
#visualization - the bedrooms
seattle_beds['bedrooms'].plot(kind='hist');

# %%
#visualization - the prices
seattle_beds['price'].plot(kind='hist');

# %%
seattle_beds['price'].describe()
# Out:
# count       8929.00000
# mean     1065280.77814
# std       669149.32127
# min        27563.00000
# 25%       700000.00000
# 50%       895000.00000
# 75%      1240320.00000
# max     14850000.00000
# Name: price, dtype: float64

# %%
seattle_beds['condition'].value_counts()
# Out:
# Average      5762
# Good         2033
# Very Good    1021
# Fair           87
# Poor           26
# Name: condition, dtype: int64

# %%
seattle_beds.groupby('grade')['price'].mean().sort_values(ascending=False)
# Out:
# grade
# 13 Mansion      9571024.66667
# 12 Luxury       5054500.00000
# 11 Excellent    3805332.63415
# 10 Very Good    2466917.36620
# 9 Better        1582074.02817
# 8 Good          1100977.09572
# 7 Average        902937.08240
# 6 Low Average    685611.02212
# 4 Low            638333.33333
# 5 Fair           635384.71154
# Name: price, dtype: float64

# %%
df_80['mean_price'] = df_80['price'].mean()
df_80.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10441 entries, 0 to 29219
# Data columns (total 35 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             10441 non-null  int64
#  1   date           10441 non-null  object
#  2   price          10441 non-null  float64
#  3   bedrooms       10441 non-null  int64
#  4   bathrooms      10441 non-null  float64
#  5   sqft_living    10441 non-null  int64
#  6   sqft_lot       10441 non-null  int64
#  7   floors         10441 non-null  float64
#  8   waterfront     10441 non-null  object
#  9   greenbelt      10441 non-null  object
#  10  nuisance       10441 non-null  object
#  11  view           10441 non-null  object
#  12  condition      10441 non-null  object
#  13  grade          10441 non-null  object
#  14  heat_source    10436 non-null  object
#  15  sewer_system   10439 non-null  object
#  16  sqft_above     10441 non-null  int64
#  17  sqft_basement  10441 non-null  int64
#  18  sqft_garage    10441 non-null  int64
#  19  sqft_patio     10441 non-null  int64
#  20  yr_built       10441 non-null  int64
#  21  yr_renovated   10441 non-null  int64
#  22  address        10441 non-null  object
#  23  lat            10441 non-null  float64
#  24  long           10441 non-null  float64
#  25  city           10441 non-null  object
#  26  zipcode        10441 non-null  int64
#  27  STATE          10441 non-null  object
#  28  ZIPCODE        10441 non-null  int64
#  29  N02650         10441 non-null  float64
#  30  A02650         10441 non-null  float64
#  31  avg_inc        10441 non-null  float64
#  32  month          10441 non-null  int64
#  33  year           10441 non-null  int64
#  34  mean_price     10441 non-null  float64
# dtypes: float64(9), int64(14), object(12)
# memory usage: 2.9+ MB

# %%
y = df_80['price']
x = df_80['mean_price']
model = sm.OLS(y,sm.add_constant(x)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Tue, 14 Feb 2023   Prob (F-statistic):                nan
# Time:                        15:54:17   Log-Likelihood:            -1.4758e+05
# No. Observations:               10441   AIC:                         2.952e+05
# Df Residuals:                   10440   BIC:                         2.952e+05
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# mean_price     1.0000      0.005    220.771      0.000       0.991       1.009
# ==============================================================================
# Omnibus:                     9899.354   Durbin-Watson:                   1.750
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1130395.610
# Skew:                           4.239   Prob(JB):                         0.00
# Kurtosis:                      53.264   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df_80.corr()['price'].sort_values(ascending=False)
# Out:
# price            1.00000
# sqft_living      0.50561
# sqft_above       0.40152
# bathrooms        0.37276
# avg_inc          0.27670
# sqft_patio       0.27633
# sqft_basement    0.22730
# lat              0.22653
# bedrooms         0.20818
# floors           0.18431
# sqft_lot         0.16976
# sqft_garage      0.16696
# A02650           0.12198
# year             0.10972
# zipcode          0.10702
# ZIPCODE          0.10702
# yr_renovated     0.09418
# yr_built         0.09002
# N02650          -0.01442
# id              -0.03621
# long            -0.05000
# month           -0.08366
# mean_price           NaN
# Name: price, dtype: float64

# %%
y = df_80['price']
x = df_80['sqft_living']
model = sm.OLS(y,sm.add_constant(x)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.256
# Model:                            OLS   Adj. R-squared:                  0.256
# Method:                 Least Squares   F-statistic:                     3585.
# Date:                Tue, 14 Feb 2023   Prob (F-statistic):               0.00
# Time:                        15:55:25   Log-Likelihood:            -1.4604e+05
# No. Observations:               10441   AIC:                         2.921e+05
# Df Residuals:                   10439   BIC:                         2.921e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        2.826e+05   7823.320     36.125      0.000    2.67e+05    2.98e+05
# sqft_living   237.6185      3.969     59.876      0.000     229.839     245.398
# ==============================================================================
# Omnibus:                    11272.681   Durbin-Watson:                   1.582
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2794147.321
# Skew:                           5.031   Prob(JB):                         0.00
# Kurtosis:                      82.508   Cond. No.                     5.48e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.48e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df_80.corr()
# Out:
#                     id    price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.00000 -0.03621   0.00382    0.00606     -0.03085  -0.10438
# price         -0.03621  1.00000   0.20818    0.37276      0.50561   0.16976
# bedrooms       0.00382  0.20818   1.00000    0.50833      0.57961  -0.00110
# bathrooms      0.00606  0.37276   0.50833    1.00000      0.71800   0.02366
# sqft_living   -0.03085  0.50561   0.57961    0.71800      1.00000   0.10366
# sqft_lot      -0.10438  0.16976  -0.00110    0.02366      0.10366   1.00000
# floors         0.02852  0.18431   0.21972    0.44414      0.37187  -0.01455
# sqft_above    -0.03776  0.40152   0.50090    0.59642      0.83738   0.11078
# sqft_basement  0.00733  0.22730   0.14749    0.23547      0.31278   0.01027
# sqft_garage   -0.00749  0.16696   0.34218    0.47938      0.48179   0.04148
# sqft_patio    -0.02919  0.27633   0.11868    0.27556      0.35122   0.09818
# yr_built       0.00536  0.09002   0.27448    0.54107      0.39482  -0.01905
# yr_renovated  -0.02353  0.09418  -0.01590    0.01292      0.01307   0.01652
# lat            0.04666  0.22653  -0.16541   -0.14618     -0.17417  -0.13360
# long          -0.04510 -0.05000   0.10810    0.09880      0.13194   0.10049
# zipcode        0.01224  0.10702  -0.17424   -0.15714     -0.16064  -0.07874
# ZIPCODE        0.01224  0.10702  -0.17424   -0.15714     -0.16064  -0.07874
# N02650         0.02427 -0.01442   0.12443    0.10024      0.08999  -0.05469
# A02650         0.01574  0.12198   0.07898    0.08477      0.08573  -0.04473
# avg_inc       -0.01695  0.27670  -0.07472   -0.00181      0.01662   0.03739
# month         -0.00781 -0.08366   0.00822    0.01407      0.00909   0.00728
# year           0.00588  0.10972  -0.01833   -0.02775     -0.02177  -0.01029
# mean_price         NaN      NaN       NaN        NaN          NaN       NaN
#
#                 floors  sqft_above  sqft_basement  sqft_garage  ...      lat  \
# id             0.02852    -0.03776        0.00733     -0.00749  ...  0.04666
# price          0.18431     0.40152        0.22730      0.16696  ...  0.22653
# bedrooms       0.21972     0.50090        0.14749      0.34218  ... -0.16541
# bathrooms      0.44414     0.59642        0.23547      0.47938  ... -0.14618
# sqft_living    0.37187     0.83738        0.31278      0.48179  ... -0.17417
# sqft_lot      -0.01455     0.11078        0.01027      0.04148  ... -0.13360
# floors         1.00000     0.54841       -0.26978      0.20480  ... -0.06817
# sqft_above     0.54841     1.00000       -0.16589      0.50878  ... -0.26500
# sqft_basement -0.26978    -0.16589        1.00000      0.04905  ...  0.16443
# sqft_garage    0.20480     0.50878        0.04905      1.00000  ... -0.30905
# sqft_patio     0.09074     0.24700        0.20320      0.17785  ... -0.08933
# yr_built       0.60669     0.48977       -0.18283      0.49040  ... -0.26257
# yr_renovated  -0.03367    -0.00884        0.03062     -0.11284  ...  0.04623
# lat           -0.06817    -0.26500        0.16443     -0.30905  ...  1.00000
# long           0.09170     0.20356       -0.13186      0.20535  ... -0.35918
# zipcode       -0.08468    -0.24657        0.15283     -0.29746  ...  0.49240
# ZIPCODE       -0.08468    -0.24657        0.15283     -0.29746  ...  0.49240
# N02650         0.04566     0.11726       -0.05430      0.20845  ...  0.05613
# A02650         0.05306     0.09449       -0.01733      0.12956  ...  0.25561
# avg_inc        0.02451    -0.01634        0.06687     -0.11807  ...  0.34417
# month          0.00155    -0.00376        0.01396     -0.00353  ... -0.00431
# year          -0.01281    -0.01294       -0.00373     -0.00540  ...  0.01589
# mean_price         NaN         NaN            NaN          NaN  ...      NaN
#
#                   long  zipcode  ZIPCODE   N02650   A02650  avg_inc    month  \
# id            -0.04510  0.01224  0.01224  0.02427  0.01574 -0.01695 -0.00781
# price         -0.05000  0.10702  0.10702 -0.01442  0.12198  0.27670 -0.08366
# bedrooms       0.10810 -0.17424 -0.17424  0.12443  0.07898 -0.07472  0.00822
# bathrooms      0.09880 -0.15714 -0.15714  0.10024  0.08477 -0.00181  0.01407
# sqft_living    0.13194 -0.16064 -0.16064  0.08999  0.08573  0.01662  0.00909
# sqft_lot       0.10049 -0.07874 -0.07874 -0.05469 -0.04473  0.03739  0.00728
# floors         0.09170 -0.08468 -0.08468  0.04566  0.05306  0.02451  0.00155
# sqft_above     0.20356 -0.24657 -0.24657  0.11726  0.09449 -0.01634 -0.00376
# sqft_basement -0.13186  0.15283  0.15283 -0.05430 -0.01733  0.06687  0.01396
# sqft_garage    0.20535 -0.29746 -0.29746  0.20845  0.12956 -0.11807 -0.00353
# sqft_patio     0.03087 -0.04778 -0.04778 -0.02812 -0.01174  0.05916  0.01825
# yr_built       0.20298 -0.24611 -0.24611  0.14962  0.09320 -0.08516  0.00648
# yr_renovated  -0.04062  0.05119  0.05119 -0.05442 -0.02887  0.05465  0.01273
# lat           -0.35918  0.49240  0.49240  0.05613  0.25561  0.34417 -0.00431
# long           1.00000 -0.13235 -0.13235  0.11317  0.11083 -0.06075 -0.00735
# zipcode       -0.13235  1.00000  1.00000 -0.21411 -0.11213  0.13134 -0.01131
# ZIPCODE       -0.13235  1.00000  1.00000 -0.21411 -0.11213  0.13134 -0.01131
# N02650         0.11317 -0.21411 -0.21411  1.00000  0.87321 -0.13515 -0.01623
# A02650         0.11083 -0.11213 -0.11213  0.87321  1.00000  0.34425 -0.01527
# avg_inc       -0.06075  0.13134  0.13134 -0.13515  0.34425  1.00000  0.00008
# month         -0.00735 -0.01131 -0.01131 -0.01623 -0.01527  0.00008  1.00000
# year          -0.00328  0.02000  0.02000  0.01148  0.01452  0.00623 -0.83925
# mean_price         NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#                   year  mean_price
# id             0.00588         NaN
# price          0.10972         NaN
# bedrooms      -0.01833         NaN
# bathrooms     -0.02775         NaN
# sqft_living   -0.02177         NaN
# sqft_lot      -0.01029         NaN
# floors        -0.01281         NaN
# sqft_above    -0.01294         NaN
# sqft_basement -0.00373         NaN
# sqft_garage   -0.00540         NaN
# sqft_patio    -0.02043         NaN
# yr_built      -0.02255         NaN
# yr_renovated  -0.00802         NaN
# lat            0.01589         NaN
# long          -0.00328         NaN
# zipcode        0.02000         NaN
# ZIPCODE        0.02000         NaN
# N02650         0.01148         NaN
# A02650         0.01452         NaN
# avg_inc        0.00623         NaN
# month         -0.83925         NaN
# year           1.00000         NaN
# mean_price         NaN         NaN
#
# [23 rows x 23 columns]

# %%
y = df_80['price']
x = df_80[['sqft_living','avg_inc','bedrooms','sqft_lot','sqft_patio','bathrooms']]
model = sm.OLS(y,sm.add_constant(x)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.351
# Model:                            OLS   Adj. R-squared:                  0.351
# Method:                 Least Squares   F-statistic:                     941.6
# Date:                Tue, 14 Feb 2023   Prob (F-statistic):               0.00
# Time:                        15:58:05   Log-Likelihood:            -1.4533e+05
# No. Observations:               10441   AIC:                         2.907e+05
# Df Residuals:                   10434   BIC:                         2.907e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -1.202e+05   2.07e+04     -5.817      0.000   -1.61e+05   -7.97e+04
# sqft_living   223.0848      5.946     37.518      0.000     211.429     234.740
# avg_inc      5542.2885    173.155     32.008      0.000    5202.871    5881.706
# bedrooms    -4.106e+04   4930.290     -8.328      0.000   -5.07e+04   -3.14e+04
# sqft_lot        0.4945      0.039     12.758      0.000       0.419       0.571
# sqft_patio    122.8200     12.959      9.478      0.000      97.418     148.222
# bathrooms    2.245e+04   5192.061      4.324      0.000    1.23e+04    3.26e+04
# ==============================================================================
# Omnibus:                    11748.619   Durbin-Watson:                   1.725
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3912672.847
# Skew:                           5.323   Prob(JB):                         0.00
# Kurtosis:                      97.236   Cond. No.                     5.61e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.61e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
